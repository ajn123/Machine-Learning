# %% [markdown]
# This is for predicting housing prices under the Kaggle Competition
# - Link [Here](https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/overview)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



train = pd.read_csv('./datasets/house-prices-advanced-regression-techniques/train.csv')
test = pd.read_csv('./datasets/house-prices-advanced-regression-techniques/test.csv')


train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
t = train.select_dtypes(object)
print(t.loc[:, t.nunique() > 5].columns)



t.columns[t.nunique() > 5 & t.dtypes == 'object']
# Out:
# Index(['Neighborhood', 'Condition1', 'Condition2', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'Foundation', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'Functional', 'GarageType', 'SaleType',
#        'SaleCondition'],
#       dtype='object')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Machine-Learning/.conda/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:362, in na_logical_op(x, y, op)
#     353 try:
#     354     # For exposition, write:
#     355     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     360     # Then Cases where this goes through without raising include:
#     361     #  (xint or xbool) and (yint or bool)
# --> 362     result = op(x, y)
#     363 except TypeError:
#
# ...

# %%
print(train.dtypes.value_counts())

print(train.YrSold.value_counts(dropna=False))

print(train.PoolQC.unique())
# Out:
# object     43
# int64      35
# float64     3
# Name: count, dtype: int64
# YrSold
# 2009    338
# 2007    329
# 2006    314
# 2008    304
# 2010    175
# Name: count, dtype: int64
# [nan 'Ex' 'Fa' 'Gd']

# %%
def transform_features(df):
    df = (
    df.assign(YrSold=lambda x: x.YrSold.astype('category'),
              )
    )
    return df



transform_features(train)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
def encode_columns(df):
    one_hot_encoded_columns = []
    for col in df.columns:
        if len(df[col].unique()) <= 5:
            one_hot_encoded_columns.append(col)
            
    return one_hot_encoded_columns

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import make_column_selector, make_column_transformer
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression

from category_encoders import TargetEncoder

import sklearn
sklearn.set_config(transform_output="pandas")


y = train['SalePrice']
X = train.drop('SalePrice', axis=1)

#one_hot_encoded_columns= one_hot_encoded_columns.remove("SalePrice")

column_trans = make_column_transformer(
    (TargetEncoder(), make_column_selector(dtype_exclude=[np.number])),
    verbose_feature_names_out=False, remainder='passthrough'
)

object_trans = make_column_transformer(
    (OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1), make_column_selector(dtype_include=object)),
    verbose_feature_names_out=False, remainder='passthrough'
)

imputer = make_column_transformer(
    (SimpleImputer(strategy="most_frequent"), make_column_selector(dtype_include=[np.generic])),
     remainder='passthrough', verbose_feature_names_out=False
)

pipe = make_pipeline(column_trans, object_trans, imputer,)



from sklearn.model_selection import cross_val_score


cross_val_score(make_pipeline(pipe, LinearRegression()), X,y, cv=3, scoring='neg_root_mean_squared_error')



pipe.fit_transform(X,y).shape
# Out:
# (1460, 80)

# %% [markdown]
# Let's try rigdge Regression

# %%
params = {'ridge__alpha':  np.linspace(25,35,40)}


from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV

ridge = Ridge()
ridge = make_pipeline(pipe, ridge)

rscv = RandomizedSearchCV(
    ridge,
    params,
    cv=4, 
    scoring='neg_root_mean_squared_error',
    return_train_score=True,
    refit=True
)


rscv.fit(X,y)
print(rscv.best_score_)
print(rscv.best_params_)
# Out:
# /Users/alexander.norton/Documents/Machine-Learning/.conda/lib/python3.11/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# /Users/alexander.norton/Documents/Machine-Learning/.conda/lib/python3.11/site-packages/category_encoders/ordinal.py:198: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X[column] = X[column].astype("object").fillna(np.nan).map(col_mapping)
# ...

# %% [markdown]
# Let's Try Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures


# cross_val_score(make_pipeline(pipe, PolynomialFeatures(degree=2), LinearRegression()), X,y, cv=3, scoring='neg_root_mean_squared_error', verbose=True)
# Out:
# array([-423259.10140139, -541404.99371108, -363075.51181738])

# %% [markdown]
# Let's try XGBoost

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, shuffle=True, random_state=42)

#cross_val_score(make_pipeline(pipe, XGBRegressor(n_estimators=1000)), X,y, cv=3, scoring="neg_root_mean_squared_error", verbose=True)


xgboostr = XGBRegressor(n_estimators = 1000, learning_rate=.05)

pipe = make_pipeline(pipe, xgboostr)
model = pipe.fit(X_train,y_train)

# %%
from sklearn.feature_selection import RFECV
from sklearn.ensemble import RandomForestRegressor


selector = RFECV(RandomForestRegressor(), step=1, cv=5, scoring="neg_root_mean_squared_error", min_features_to_select=15)


X = pipe.fit_transform(X,y)
selector.fit(X,y)

print(selector.support_)
# Out:
# [False False False False False False False False  True False False False
#  False False False False False False  True False False  True False  True
#  False False False False False False  True False  True  True False False
#  False False False False False False False  True False  True  True  True
#   True  True  True  True  True False  True  True  True  True False  True
#  False False False False False False  True False  True  True  True  True
#   True False False False False False  True False]

# %% [markdown]
# # Submission

# %%
X
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
results = model.predict(test)

submission = pd.DataFrame()

submission['Id'] = test.Id
submission['SalePrice'] = results

submission.to_csv("submissions/HousingPrices.csv", header=True, index=False)
